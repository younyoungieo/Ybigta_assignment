# %% [markdown]
# ### 필요 Package download

# %%
import torch
import torchvision
import torchvision.transforms as transforms

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# 현재 gpu를 사용중이면 cuda로 출력됩니다!:
# gpu 변경은 런타임 -> 런타임 유형변경 -> 하드웨어 가속기: GPU로 할 수 있습니다.

print(device)
# Out:
# cpu

# %% [markdown]
# ## 데이터 부연설명
# * 저희가 사용할 dataset은 cifar-10이라는 이름을 가진, 컬러 이미지 데이터 60,000개가 들어있는
# dataset입니다. <br>
# * 해당 dataset은 총 10개의 class로 나누어져 있으며, 이 task는 각 이미지에 대한 class의 분류 accuracy를 높이는 것이 목적입니다.

# %% [markdown]
# ### Data Normalize & DataLoader Settting

# %%
transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=4,
                                          shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=4,
                                         shuffle=False, num_workers=2)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
import matplotlib.pyplot as plt
import numpy as np

# 이미지를 보여주기 위한 함수

def imshow(img):
    img = img / 2 + 0.5     # 표준화 해제
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))


# 학습용 이미지를 무작위로 가져오기
dataiter = iter(trainloader)
images, labels = dataiter.__next__()

# 이미지 보여주기
imshow(torchvision.utils.make_grid(images))
# 정답(label) 출력
print(' '.join('%5s' % classes[labels[j]] for j in range(4)))
plt.show()
# Out:
# plane  deer  deer  frog

# %%
import torch.nn as nn
import torch.nn.functional as F

#해당 부분은 어느 정도 CNN의 개념이 포함되어 있습니다! 과제를 수행하는데 아무 관련도 없으니 그대로 두시면 됩니다!
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(3, 6, 5) # input channels, output channels, kernel size
        self.pool = nn.MaxPool2d(2, 2)  # kernel size, stride, padding = 0 (default)
        self.conv2 = nn.Conv2d(6, 16, 5)
        #아래 부분의 코드를 수정 혹은 추가해주시면 됩니다! (layer를 추가할때는 self.fc'num'=nn.Linear(x,y)의 형태로 추가하시면 됩니다!)
        self.fc1 = nn.Linear(400, 200) # input features, output features
        self.fc2 = nn.Linear(200, 120)
        self.fc3 = nn.Linear(120, 60)
        self.fc4 = nn.Linear(60, 30)
        self.fc5 = nn.Linear(30, 10)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = x.view(-1, 16 * 5 * 5)
        #아래 부분에서 코드를 수정하거나 추가하여 forward 함수를 새롭게 지정해주시기 바랍니다!
        #Hint: relu 함수는 출력층을 제외한 모든 층에서 활성화 함수로써 작동되어야 합니다.
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        x = F.relu(self.fc4(x))
        x = self.fc5(x)
        return x


net = Net()

# %%
import torch.optim as optim

#optimizer를 변경하거나 수치를 조정해보는 것도 accuracy를 높이는 데 도움을 줄 수 있습니다!
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum = 0.9)

# %%
for epoch in range(30):  # 데이터셋을 n차례 반복하여 학습합니다. 또한 range 속의 숫자도 바꾸어 학습률을 높이는 것도 도움이 될 겁니다!

    running_loss = 0.0
    for i, data in enumerate(trainloader, 0):
        # 입력을 받은 후
        inputs, labels = data
        # 변화도(Gradient) 매개변수를 0으로 만든 후
        optimizer.zero_grad()

        # 순전파 + 역전파 + 최적화
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        # 통계 출력

        running_loss += loss.item()
        # 2000개의 data를 학습할때마다 loss 출력
        if i % 2000 == 1999:    # % 뒤에 들어갈 숫자의 크기를 조정하여 batch_size를 조정할 수 있습니다! 그리고 i % n == n-1:로 숫자를 맞춰주셔야 한다는 점 잊지 마세요!
            print('[%d, %5d] epoch loss: %.3f' %
                  (epoch + 1, i + 1, running_loss / 2000)) # running_loss 우측의 숫자 역시 윗줄에서 바꾼 batch_size로 바꿔주어야 합니다!
            running_loss = 0.0

print('Finished Training')
# Out:
# [1,  2000] epoch loss: 2.305
# [1,  4000] epoch loss: 2.303
# [1,  6000] epoch loss: 2.302
# [1,  8000] epoch loss: 2.267
# [1, 10000] epoch loss: 2.036
# [1, 12000] epoch loss: 1.862
# [2,  2000] epoch loss: 1.742
# [2,  4000] epoch loss: 1.646
# [2,  6000] epoch loss: 1.592
# [2,  8000] epoch loss: 1.530
# [2, 10000] epoch loss: 1.482
# [2, 12000] epoch loss: 1.448
# [3,  2000] epoch loss: 1.401
# [3,  4000] epoch loss: 1.366
# [3,  6000] epoch loss: 1.354
# [3,  8000] epoch loss: 1.331
# [3, 10000] epoch loss: 1.326
# [3, 12000] epoch loss: 1.284
# [4,  2000] epoch loss: 1.216
# [4,  4000] epoch loss: 1.218
# [4,  6000] epoch loss: 1.240
# [4,  8000] epoch loss: 1.206
# [4, 10000] epoch loss: 1.209
# [4, 12000] epoch loss: 1.182
# [5,  2000] epoch loss: 1.111
# [5,  4000] epoch loss: 1.104
# [5,  6000] epoch loss: 1.124
# [5,  8000] epoch loss: 1.109
# [5, 10000] epoch loss: 1.135
# [5, 12000] epoch loss: 1.103
# [6,  2000] epoch loss: 1.036
# [6,  4000] epoch loss: 1.033
# [6,  6000] epoch loss: 1.026
# [6,  8000] epoch loss: 1.040
# [6, 10000] epoch loss: 1.037
# [6, 12000] epoch loss: 1.035
# [7,  2000] epoch loss: 0.940
# [7,  4000] epoch loss: 0.953
# [7,  6000] epoch loss: 0.970
# [7,  8000] epoch loss: 0.973
# [7, 10000] epoch loss: 0.992
# [7, 12000] epoch loss: 0.987
# [8,  2000] epoch loss: 0.861
# [8,  4000] epoch loss: 0.916
# [8,  6000] epoch loss: 0.905
# [8,  8000] epoch loss: 0.916
# [8, 10000] epoch loss: 0.926
# [8, 12000] epoch loss: 0.935
# [9,  2000] epoch loss: 0.819
# [9,  4000] epoch loss: 0.840
# [9,  6000] epoch loss: 0.869
# [9,  8000] epoch loss: 0.866
# [9, 10000] epoch loss: 0.874
# [9, 12000] epoch loss: 0.900
# [10,  2000] epoch loss: 0.778
# [10,  4000] epoch loss: 0.800
# [10,  6000] epoch loss: 0.811
# [10,  8000] epoch loss: 0.839
# [10, 10000] epoch loss: 0.810
# [10, 12000] epoch loss: 0.838
# [11,  2000] epoch loss: 0.716
# [11,  4000] epoch loss: 0.758
# [11,  6000] epoch loss: 0.771
# [11,  8000] epoch loss: 0.783
# [11, 10000] epoch loss: 0.788
# [11, 12000] epoch loss: 0.816
# [12,  2000] epoch loss: 0.666
# [12,  4000] epoch loss: 0.725
# [12,  6000] epoch loss: 0.723
# [12,  8000] epoch loss: 0.757
# [12, 10000] epoch loss: 0.763
# [12, 12000] epoch loss: 0.779
# [13,  2000] epoch loss: 0.643
# [13,  4000] epoch loss: 0.673
# [13,  6000] epoch loss: 0.681
# [13,  8000] epoch loss: 0.709
# [13, 10000] epoch loss: 0.710
# [13, 12000] epoch loss: 0.732
# [14,  2000] epoch loss: 0.608
# [14,  4000] epoch loss: 0.636
# [14,  6000] epoch loss: 0.660
# [14,  8000] epoch loss: 0.675
# [14, 10000] epoch loss: 0.700
# [14, 12000] epoch loss: 0.714
# [15,  2000] epoch loss: 0.564
# [15,  4000] epoch loss: 0.620
# [15,  6000] epoch loss: 0.617
# [15,  8000] epoch loss: 0.652
# [15, 10000] epoch loss: 0.666
# [15, 12000] epoch loss: 0.690
# [16,  2000] epoch loss: 0.547
# [16,  4000] epoch loss: 0.592
# [16,  6000] epoch loss: 0.593
# [16,  8000] epoch loss: 0.638
# [16, 10000] epoch loss: 0.667
# [16, 12000] epoch loss: 0.632
# [17,  2000] epoch loss: 0.530
# [17,  4000] epoch loss: 0.561
# [17,  6000] epoch loss: 0.590
# [17,  8000] epoch loss: 0.613
# [17, 10000] epoch loss: 0.626
# [17, 12000] epoch loss: 0.636
# [18,  2000] epoch loss: 0.499
# [18,  4000] epoch loss: 0.520
# [18,  6000] epoch loss: 0.551
# [18,  8000] epoch loss: 0.568
# [18, 10000] epoch loss: 0.586
# [18, 12000] epoch loss: 0.595
# [19,  2000] epoch loss: 0.495
# [19,  4000] epoch loss: 0.514
# [19,  6000] epoch loss: 0.519
# [19,  8000] epoch loss: 0.547
# [19, 10000] epoch loss: 0.559
# [19, 12000] epoch loss: 0.576
# [20,  2000] epoch loss: 0.468
# [20,  4000] epoch loss: 0.516
# [20,  6000] epoch loss: 0.499
# [20,  8000] epoch loss: 0.551
# [20, 10000] epoch loss: 0.540
# [20, 12000] epoch loss: 0.575
# [21,  2000] epoch loss: 0.439
# [21,  4000] epoch loss: 0.467
# [21,  6000] epoch loss: 0.502
# [21,  8000] epoch loss: 0.536
# [21, 10000] epoch loss: 0.512
# [21, 12000] epoch loss: 0.525
# [22,  2000] epoch loss: 0.420
# [22,  4000] epoch loss: 0.456
# [22,  6000] epoch loss: 0.461
# [22,  8000] epoch loss: 0.497
# [22, 10000] epoch loss: 0.489
# [22, 12000] epoch loss: 0.529
# [23,  2000] epoch loss: 0.436
# [23,  4000] epoch loss: 0.454
# [23,  6000] epoch loss: 0.463
# [23,  8000] epoch loss: 0.469
# [23, 10000] epoch loss: 0.494
# [23, 12000] epoch loss: 0.515
# [24,  2000] epoch loss: 0.398
# [24,  4000] epoch loss: 0.428
# [24,  6000] epoch loss: 0.452
# [24,  8000] epoch loss: 0.469
# [24, 10000] epoch loss: 0.483
# [24, 12000] epoch loss: 0.495
# [25,  2000] epoch loss: 0.383
# [25,  4000] epoch loss: 0.414
# [25,  6000] epoch loss: 0.448
# [25,  8000] epoch loss: 0.453
# [25, 10000] epoch loss: 0.479
# [25, 12000] epoch loss: 0.483
# [26,  2000] epoch loss: 0.370
# [26,  4000] epoch loss: 0.413
# [26,  6000] epoch loss: 0.431
# [26,  8000] epoch loss: 0.428
# [26, 10000] epoch loss: 0.457
# [26, 12000] epoch loss: 0.478
# [27,  2000] epoch loss: 0.371
# [27,  4000] epoch loss: 0.386
# [27,  6000] epoch loss: 0.412
# [27,  8000] epoch loss: 0.415
# [27, 10000] epoch loss: 0.442
# [27, 12000] epoch loss: 0.466
# [28,  2000] epoch loss: 0.332
# [28,  4000] epoch loss: 0.373
# [28,  6000] epoch loss: 0.399
# [28,  8000] epoch loss: 0.426
# [28, 10000] epoch loss: 0.457
# [28, 12000] epoch loss: 0.469
# [29,  2000] epoch loss: 0.357
# [29,  4000] epoch loss: 0.372
# [29,  6000] epoch loss: 0.402
# [29,  8000] epoch loss: 0.414
# [29, 10000] epoch loss: 0.433
# [29, 12000] epoch loss: 0.437
# [30,  2000] epoch loss: 0.339
# [30,  4000] epoch loss: 0.356
# [30,  6000] epoch loss: 0.366
# [30,  8000] epoch loss: 0.413
# [30, 10000] epoch loss: 0.426
# [30, 12000] epoch loss: 0.429
# Finished Training

# %%
dataiter = iter(testloader)
images, labels = dataiter.__next__()

# print images
imshow(torchvision.utils.make_grid(images))
print('GroundTruth: ', ' '.join('%5s' % classes[labels[j]] for j in range(4)))
plt.show()
# Out:
# GroundTruth:    cat  ship  ship plane

# %%
outputs = net(images)
_, predicted = torch.max(outputs, 1)

print('Predicted: ', ' '.join('%5s' % classes[predicted[j]]
                              for j in range(4)))
# Out:
# Predicted:    cat  ship plane   car

# %%
#과제2에서 요구하는 accuracy의 결과값이 나오는 code입니다! 캡처를 하실 때는 해당 코드의 결과를 캡처하시고, 이를 제출하여 주시기 바랍니다~
correct = 0
total = 0
with torch.no_grad():
    for data in testloader:
        images, labels = data
        outputs = net(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print('Accuracy of the network on the 10000 test images: %d %%' % (
    100 * correct / total))
# Out:
# Accuracy of the network on the 10000 test images: 60 %

# %%
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))
with torch.no_grad():
    for data in testloader:
        images, labels = data
        outputs = net(images)
        _, predicted = torch.max(outputs, 1)
        c = (predicted == labels).squeeze()
        for i in range(4):
            label = labels[i]
            class_correct[label] += c[i].item()
            class_total[label] += 1


for i in range(10):
    print('Accuracy of %5s : %2d %%' % (
        classes[i], 100 * class_correct[i] / class_total[i]))
# Out:
# Accuracy of plane : 59 %
# Accuracy of   car : 78 %
# Accuracy of  bird : 58 %
# Accuracy of   cat : 40 %
# Accuracy of  deer : 60 %
# Accuracy of   dog : 38 %
# Accuracy of  frog : 62 %
# Accuracy of horse : 62 %
# Accuracy of  ship : 75 %
# Accuracy of truck : 71 %

# %% [markdown]
# 출처: https://m.blog.naver.com/ckdgus1433/221406102936의 튜토리얼을 참고하였습니다!

# %% [markdown]
# #과제

# %% [markdown]
# ##1. 실습 파일의 overfitting model의 optimizer, epoch, learning rate 등을 변경하여 실행한 결과와, underfitting의 layer를 2개 이상 추가하여 실행한 결과를 각각 캡처하여 overfit, underfit이라는 이름으로 깃허브에 제출하기.

# %% [markdown]
# ##2. 과제 파일을 수정하여 Test image에 대한 accuracy를 53% 이상으로 높이고, 모델의 결과에 대한 캡처본과 파일을 모두 깃허브에 제출하기. <br>
# Hint: 파일 중간중간에 설명이 있는 부분을 참고하시면 아마 될 겁니다!<br>
# (layer 추가, optimizer 변경, learning rate 조정 등...)

# %% [markdown]
# ##3. MLP model과 기존 ML model의 차이점을 최소 2가지 측면에서 서술하기.
#
# 답1: (구조) MLP 모델은 신경망 구조로 이루어져 있으며, 여러 개의 은닉층(hidden layer)을 포함할 수 있습니다. 이에 반해 기존의 ML 모델은 주로 선형 모델이나 결정 트리 등 단일 모델로 구성됩니다. MLP 모델은 비선형성을 표현할 수 있는 다양한 활성화 함수와 은닉층을 통해 복잡한 패턴을 학습할 수 있습니다.
#
# 답2: (대상 데이터의 종류) MLP 모델은 이미지, 음성, 텍스트 등 다양한 데이터 유형에 적용할 수 있으며, 딥러닝의 기반이 되는 모델입니다. 기존의 ML 모델은 주로 특정한 문제에 특화된 모델로 사용되며, 데이터의 특성에 따라 적합한 모델을 선택하여 사용합니다.

# %% [markdown]
# ##4. Backpropagation이 무엇인지 자신의 언어로 한줄 요약!
#
# 답: Backpropagation은 MLP에서 오차를 최소화하기 위해 출력층에서 입력층으로 역으로 가중치를 조정하는 학습 알고리즘입니다.
